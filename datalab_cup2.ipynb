# %% [markdown]
# <a href="https://colab.research.google.com/github/audreych23/Banana-Ripeness-Classification/blob/main/datalab_cup2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Datalab-cup2
# [Kaggle](https://www.kaggle.com/competitions/2023-datalab-cup-2-cnn-for-object-detection/)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Shareddrives/DL_Competition/Cup_2/2023-datalab-cup2-object-detection/
# Out:
# /content/drive/Shareddrives/DL_Competition/Cup_2/2023-datalab-cup2-object-detection

# %% [markdown]
# ## Data Provided

# %%
classes_name =  ["aeroplane", "bicycle", "bird", "boat", "bottle",
                 "bus", "car", "cat", "chair", "cow", "diningtable",
                 "dog", "horse", "motorbike", "person", "pottedplant",
                 "sheep", "sofa", "train","tvmonitor"]

# %% [markdown]
# ### Processed Data Format

# %%
training_data_file = open("./pascal_voc_training_data.txt", "r")
for i, line in enumerate(training_data_file):
    if i >5:
        break
    line = line.strip()
    print(line)
# Out:
# 000005.jpg 263 211 324 339 8 165 264 253 372 8 5 244 67 374 8 241 194 295 299 8 277 186 312 220 8
# 000007.jpg 141 50 500 330 6
# 000009.jpg 69 172 270 330 12 150 141 229 284 14 285 201 327 331 14 258 198 297 329 14
# 000012.jpg 156 97 351 270 6
# 000016.jpg 92 72 305 473 1
# 000017.jpg 185 62 279 199 14 90 78 403 336 12

# %%
import tensorflow as tf
import numpy as np

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        # Select GPU number 1
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# common params
IMAGE_SIZE = 448
BATCH_SIZE = 8
NUM_CLASSES = 20
MAX_OBJECTS_PER_IMAGE = 20

# dataset params
DATA_PATH = './pascal_voc_training_data.txt'
IMAGE_DIR = './VOCdevkit_train/VOC2007/JPEGImages/'

# model params
CELL_SIZE = 7
BOXES_PER_CELL = 2
OBJECT_SCALE = 1
NOOBJECT_SCALE = 0.5
CLASS_SCALE = 1
COORD_SCALE = 5

# training params
LEARNING_RATE = 1e-4
EPOCHS = 30

# %% [markdown]
# ## Dataset Loader

# %%
class DatasetGenerator:
    """
    Load pascalVOC 2007 dataset and creates an input pipeline.
    - Reshapes images into 448 x 448
    - converts [0 1] to [-1 1]
    - shuffles the input
    - builds batches
    """

    def __init__(self):
        self.image_names = []
        self.record_list = []
        self.object_num_list = []
        # filling the record_list
        input_file = open(DATA_PATH, 'r')

        for line in input_file:
            line = line.strip()
            ss = line.split(' ')
            self.image_names.append(ss[0])

            self.record_list.append([float(num) for num in ss[1:]])

            self.object_num_list.append(min(len(self.record_list[-1])//5,
                                            MAX_OBJECTS_PER_IMAGE))
            if len(self.record_list[-1]) < MAX_OBJECTS_PER_IMAGE*5:
                # if there are objects less than MAX_OBJECTS_PER_IMAGE, pad the list
                self.record_list[-1] = self.record_list[-1] +\
                [0., 0., 0., 0., 0.]*\
                (MAX_OBJECTS_PER_IMAGE-len(self.record_list[-1])//5)

            elif len(self.record_list[-1]) > MAX_OBJECTS_PER_IMAGE*5:
               # if there are objects more than MAX_OBJECTS_PER_IMAGE, crop the list
                self.record_list[-1] = self.record_list[-1][:MAX_OBJECTS_PER_IMAGE*5]

    def _data_preprocess(self, image_name, raw_labels, object_num):
        image_file = tf.io.read_file(IMAGE_DIR+image_name)
        image = tf.io.decode_jpeg(image_file, channels=3)

        h = tf.shape(image)[0]
        w = tf.shape(image)[1]

        width_ratio  = IMAGE_SIZE * 1.0 / tf.cast(w, tf.float32)
        height_ratio = IMAGE_SIZE * 1.0 / tf.cast(h, tf.float32)

        image = tf.image.resize(image, size=[IMAGE_SIZE, IMAGE_SIZE])
        image = (image/255) * 2 - 1

        raw_labels = tf.cast(tf.reshape(raw_labels, [-1, 5]), tf.float32)

        xmin = raw_labels[:, 0]
        ymin = raw_labels[:, 1]
        xmax = raw_labels[:, 2]
        ymax = raw_labels[:, 3]
        class_num = raw_labels[:, 4]

        xcenter = (xmin + xmax) * 1.0 / 2.0 * width_ratio
        ycenter = (ymin + ymax) * 1.0 / 2.0 * height_ratio

        box_w = (xmax - xmin) * width_ratio
        box_h = (ymax - ymin) * height_ratio

        labels = tf.stack([xcenter, ycenter, box_w, box_h, class_num], axis=1)

        return image, labels, tf.cast(object_num, tf.int32)

    def generate(self):
        dataset = tf.data.Dataset.from_tensor_slices((self.image_names,
                                                      np.array(self.record_list),
                                                      np.array(self.object_num_list)))
        dataset = dataset.shuffle(BATCH_SIZE * 10)
        dataset = dataset.map(self._data_preprocess,
                              num_parallel_calls = tf.data.experimental.AUTOTUNE)
        dataset = dataset.batch(BATCH_SIZE)
        dataset = dataset.prefetch(buffer_size=200)

        return dataset

# %% [markdown]
# ## YOLO model

# %% [markdown]
# ### model

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
def conv_leaky_relu(inputs, filters, size, stride):
    x = layers.Conv2D(filters, size, stride, padding="same",
                      kernel_initializer=tf.keras.initializers.TruncatedNormal())(inputs)
    x = layers.LeakyReLU(0.1)(x)

    return x

# %%
img_inputs = keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
x = conv_leaky_relu(img_inputs, 64, 7, 2)
x = layers.MaxPool2D()(x)
x = conv_leaky_relu(x, 192, 3, 1)
x = layers.MaxPool2D()(x)
x = conv_leaky_relu(x, 128, 1, 1)
x = conv_leaky_relu(x, 256, 3, 1)
x = conv_leaky_relu(x, 256, 1, 1)
x = conv_leaky_relu(x, 512, 3, 1)
x = layers.MaxPool2D()(x)
x = conv_leaky_relu(x, 256, 1, 1)
x = conv_leaky_relu(x, 512, 3, 1)
x = conv_leaky_relu(x, 256, 1, 1)
x = conv_leaky_relu(x, 512, 3, 1)
x = conv_leaky_relu(x, 256, 1, 1)
x = conv_leaky_relu(x, 512, 3, 1)
x = conv_leaky_relu(x, 256, 1, 1)
x = conv_leaky_relu(x, 512, 3, 1)
x = conv_leaky_relu(x, 512, 1, 1)
x = conv_leaky_relu(x, 1024, 3, 1)
x = layers.MaxPool2D()(x)
x = conv_leaky_relu(x, 512, 1, 1)
x = conv_leaky_relu(x, 1024, 3, 1)
x = conv_leaky_relu(x, 512, 1, 1)
x = conv_leaky_relu(x, 1024, 3, 1)
x = conv_leaky_relu(x, 1024, 3, 1)
x = conv_leaky_relu(x, 1024, 3, 2)
x = conv_leaky_relu(x, 1024, 3, 1)
x = conv_leaky_relu(x, 1024, 3, 1)
x = layers.Flatten()(x)
x = layers.Dense(4096,
                 kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.01))(x)
x = layers.LeakyReLU(0.1)(x)
outputs = layers.Dense(1470,
                       kernel_initializer=tf.keras.initializers.TruncatedNormal(stddev=0.01))(x)

YOLO = keras.Model(inputs=img_inputs, outputs=outputs, name="YOLO")

# %%
YOLO.summary()
# Out:
# Model: "YOLO"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 448, 448, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 64)      9472
#
#  leaky_re_lu (LeakyReLU)     (None, 224, 224, 64)      0
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 192)     110784
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 112, 112, 192)     0
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 192)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       24704
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 56, 56, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 256)       295168
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 56, 56, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       65792
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 56, 56, 256)       0
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 512)       1180160
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 56, 56, 512)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 512)       0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 256)       131328
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 28, 28, 256)       0
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 28, 28, 512)       0
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 256)       131328
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 28, 28, 256)       0
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 28, 28, 512)       0
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 256)       131328
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 28, 28, 256)       0
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 28, 28, 512)       0
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 256)       131328
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 28, 28, 256)       0
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 28, 28, 512)       0
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 512)       262656
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 28, 28, 512)       0
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 1024)      4719616
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 28, 28, 1024)      0
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 1024)      0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 512)       524800
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 14, 14, 512)       0
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 1024)      4719616
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 14, 14, 1024)      0
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 512)       524800
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 14, 14, 512)       0
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 1024)      4719616
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 14, 14, 1024)      0
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 1024)      9438208
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 14, 14, 1024)      0
#
#  conv2d_21 (Conv2D)          (None, 7, 7, 1024)        9438208
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 7, 7, 1024)        0
#
#  conv2d_22 (Conv2D)          (None, 7, 7, 1024)        9438208
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 7, 7, 1024)        0
#
#  conv2d_23 (Conv2D)          (None, 7, 7, 1024)        9438208
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 7, 7, 1024)        0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 4096)              205524992
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 4096)              0
#
#  dense_1 (Dense)             (None, 1470)              6022590
#
# =================================================================
# Total params: 271703550 (1.01 GB)
# Trainable params: 271703550 (1.01 GB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Define loss

# %%
# base boxes (for loss calculation)
base_boxes = np.zeros([CELL_SIZE, CELL_SIZE, 4])

# initializtion for each cell
for y in range(CELL_SIZE):
    for x in range(CELL_SIZE):
        base_boxes[y, x, :] = [IMAGE_SIZE / CELL_SIZE * x,
                               IMAGE_SIZE / CELL_SIZE * y, 0, 0]

base_boxes = np.resize(base_boxes, [CELL_SIZE, CELL_SIZE, 1, 4])
base_boxes = np.tile(base_boxes, [1, 1, BOXES_PER_CELL, 1])

# %%
def yolo_loss(predicts, labels, objects_num, batch_size=BATCH_SIZE):
    """
    Add Loss to all the trainable variables
    Args:
        predicts: 4-D tensor [batch_size, cell_size, cell_size, num_classes + 5 * boxes_per_cell]
        ===> (num_classes, boxes_per_cell, 4 * boxes_per_cell)
        labels  : 3-D tensor of [batch_size, max_objects, 5]
        objects_num: 1-D tensor [batch_size]
    """

    loss = 0.

    #you can parallel the code with tf.map_fn or tf.vectorized_map (big performance gain!)
    for i in tf.range(batch_size):
        predict = predicts[i, :, :, :]
        label = labels[i, :, :]
        object_num = objects_num[i]

        for j in tf.range(object_num):
            results = losses_calculation(predict, label[j:j+1, :])
            loss = loss + results

    return loss/batch_size

# %%
def iou(boxes1, boxes2):
    """calculate ious
    Args:
      boxes1: 4-D tensor [CELL_SIZE, CELL_SIZE, BOXES_PER_CELL, 4]  ====> (x_center, y_center, w, h)
      boxes2: 1-D tensor [4] ===> (x_center, y_center, w, h)

    Return:
      iou: 3-D tensor [CELL_SIZE, CELL_SIZE, BOXES_PER_CELL]
      ====> iou score for each cell
    """

    #boxes1 : [4(xmin, ymin, xmax, ymax), cell_size, cell_size, boxes_per_cell]
    boxes1 = tf.stack([boxes1[:, :, :, 0] - boxes1[:, :, :, 2] / 2, boxes1[:, :, :, 1] - boxes1[:, :, :, 3] / 2,
                      boxes1[:, :, :, 0] + boxes1[:, :, :, 2] / 2, boxes1[:, :, :, 1] + boxes1[:, :, :, 3] / 2])

    #boxes1 : [cell_size, cell_size, boxes_per_cell, 4(xmin, ymin, xmax, ymax)]
    boxes1 = tf.transpose(boxes1, [1, 2, 3, 0])

    boxes2 =  tf.stack([boxes2[0] - boxes2[2] / 2, boxes2[1] - boxes2[3] / 2,
                      boxes2[0] + boxes2[2] / 2, boxes2[1] + boxes2[3] / 2])

    #calculate the left up point of boxes' overlap area
    lu = tf.maximum(boxes1[:, :, :, 0:2], boxes2[0:2])
    #calculate the right down point of boxes overlap area
    rd = tf.minimum(boxes1[:, :, :, 2:], boxes2[2:])

    #intersection
    intersection = rd - lu

    #the size of the intersection area
    inter_square = intersection[:, :, :, 0] * intersection[:, :, :, 1]

    mask = tf.cast(intersection[:, :, :, 0] > 0, tf.float32) * tf.cast(intersection[:, :, :, 1] > 0, tf.float32)

    #if intersection is negative, then the boxes don't overlap
    inter_square = mask * inter_square

    #calculate the boxs1 square and boxs2 square
    square1 = (boxes1[:, :, :, 2] - boxes1[:, :, :, 0]) * (boxes1[:, :, :, 3] - boxes1[:, :, :, 1])
    square2 = (boxes2[2] - boxes2[0]) * (boxes2[3] - boxes2[1])

    return inter_square/(square1 + square2 - inter_square + 1e-6)

def losses_calculation(predict, label):
    """
    calculate loss
    Args:
      predict: 3-D tensor [cell_size, cell_size, num_classes + 5 * boxes_per_cell]
      label : [1, 5]  (x_center, y_center, w, h, class)
    """
    label = tf.reshape(label, [-1])

    #Step A. calculate objects tensor [CELL_SIZE, CELL_SIZE]
    #turn pixel position into cell position (corner)
    min_x = (label[0] - label[2] / 2) / (IMAGE_SIZE / CELL_SIZE)
    max_x = (label[0] + label[2] / 2) / (IMAGE_SIZE / CELL_SIZE)

    min_y = (label[1] - label[3] / 2) / (IMAGE_SIZE / CELL_SIZE)
    max_y = (label[1] + label[3] / 2) / (IMAGE_SIZE / CELL_SIZE)

    min_x = tf.floor(min_x)
    min_y = tf.floor(min_y)

    max_x = tf.minimum(tf.math.ceil(max_x), CELL_SIZE)
    max_y = tf.minimum(tf.math.ceil(max_y), CELL_SIZE)

    #calculate mask of object with cells
    onset = tf.cast(tf.stack([max_y - min_y, max_x - min_x]), dtype=tf.int32)
    object_mask = tf.ones(onset, tf.float32)

    offset = tf.cast(tf.stack([min_y, CELL_SIZE - max_y, min_x, CELL_SIZE - max_x]), tf.int32)
    offset = tf.reshape(offset, (2, 2))
    object_mask = tf.pad(object_mask, offset, "CONSTANT")

    #Step B. calculate the coordination of object center and the corresponding mask
    #turn pixel position into cell position (center)
    center_x = label[0] / (IMAGE_SIZE / CELL_SIZE)
    center_x = tf.floor(center_x)

    center_y = label[1] / (IMAGE_SIZE / CELL_SIZE)
    center_y = tf.floor(center_y)

    response = tf.ones([1, 1], tf.float32)

    #calculate the coordination of object center with cells
    objects_center_coord = tf.cast(tf.stack([center_y, CELL_SIZE - center_y - 1,
                             center_x, CELL_SIZE - center_x - 1]),
                             tf.int32)
    objects_center_coord = tf.reshape(objects_center_coord, (2, 2))

    #make mask
    response = tf.pad(response, objects_center_coord, "CONSTANT")

    #Step C. calculate iou_predict_truth [CELL_SIZE, CELL_SIZE, BOXES_PER_CELL]
    predict_boxes = predict[:, :, NUM_CLASSES + BOXES_PER_CELL:]

    predict_boxes = tf.reshape(predict_boxes, [CELL_SIZE,
                                               CELL_SIZE,
                                               BOXES_PER_CELL, 4])
    #cell position to pixel position
    predict_boxes = predict_boxes * [IMAGE_SIZE / CELL_SIZE,
                                     IMAGE_SIZE / CELL_SIZE,
                                     IMAGE_SIZE, IMAGE_SIZE]

    #if there's no predict_box in that cell, then the base_boxes will be calcuated with label and got iou equals 0
    predict_boxes = base_boxes + predict_boxes

    iou_predict_truth = iou(predict_boxes, label[0:4])

    #calculate C tensor [CELL_SIZE, CELL_SIZE, BOXES_PER_CELL]
    C = iou_predict_truth * tf.reshape(response, [CELL_SIZE, CELL_SIZE, 1])

    #calculate I tensor [CELL_SIZE, CELL_SIZE, BOXES_PER_CELL]
    I = iou_predict_truth * tf.reshape(response, [CELL_SIZE, CELL_SIZE, 1])

    max_I = tf.reduce_max(I, 2, keepdims=True)

    #replace large iou scores with response (object center) value
    I = tf.cast((I >= max_I), tf.float32) * tf.reshape(response, (CELL_SIZE, CELL_SIZE, 1))

    #calculate no_I tensor [CELL_SIZE, CELL_SIZE, BOXES_PER_CELL]
    no_I = tf.ones_like(I, dtype=tf.float32) - I

    p_C = predict[:, :, NUM_CLASSES:NUM_CLASSES + BOXES_PER_CELL]

    #calculate truth x, y, sqrt_w, sqrt_h 0-D
    x = label[0]
    y = label[1]

    sqrt_w = tf.sqrt(tf.abs(label[2]))
    sqrt_h = tf.sqrt(tf.abs(label[3]))

    #calculate predict p_x, p_y, p_sqrt_w, p_sqrt_h 3-D [CELL_SIZE, CELL_SIZE, BOXES_PER_CELL]
    p_x = predict_boxes[:, :, :, 0]
    p_y = predict_boxes[:, :, :, 1]

    p_sqrt_w = tf.sqrt(tf.minimum(IMAGE_SIZE * 1.0, tf.maximum(0.0, predict_boxes[:, :, :, 2])))
    p_sqrt_h = tf.sqrt(tf.minimum(IMAGE_SIZE * 1.0, tf.maximum(0.0, predict_boxes[:, :, :, 3])))

    #calculate ground truth p 1-D tensor [NUM_CLASSES]
    P = tf.one_hot(tf.cast(label[4], tf.int32), NUM_CLASSES, dtype=tf.float32)

    #calculate predicted p_P 3-D tensor [CELL_SIZE, CELL_SIZE, NUM_CLASSES]
    p_P = predict[:, :, 0:NUM_CLASSES]

    #class_loss
    class_loss = tf.nn.l2_loss(tf.reshape(object_mask, (CELL_SIZE, CELL_SIZE, 1)) * (p_P - P)) * CLASS_SCALE

    #object_loss
    object_loss = tf.nn.l2_loss(I * (p_C - C)) * OBJECT_SCALE

    #noobject_loss
    noobject_loss = tf.nn.l2_loss(no_I * (p_C)) * NOOBJECT_SCALE

    #coord_loss
    coord_loss = (tf.nn.l2_loss(I * (p_x - x)/(IMAGE_SIZE/CELL_SIZE)) +
                  tf.nn.l2_loss(I * (p_y - y)/(IMAGE_SIZE/CELL_SIZE)) +
                  tf.nn.l2_loss(I * (p_sqrt_w - sqrt_w))/IMAGE_SIZE +
                  tf.nn.l2_loss(I * (p_sqrt_h - sqrt_h))/IMAGE_SIZE) * COORD_SCALE

    return class_loss + object_loss + noobject_loss + coord_loss

# %% [markdown]
# ## Start Training

# %%
dataset = DatasetGenerator().generate()

# %%
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)
train_loss_metric = tf.keras.metrics.Mean(name='loss')

# %%
import os
ckpt_dir = '/content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO'
os.makedirs(ckpt_dir, exist_ok = True)

# %%
ckpt = tf.train.Checkpoint(epoch=tf.Variable(0), net=YOLO)

manager = tf.train.CheckpointManager(ckpt, ckpt_dir, max_to_keep=3,
                                     checkpoint_name='yolo')
if len(os.listdir(ckpt_dir)) != 0:
    ckpt.restore(manager.latest_checkpoint)

# %%
@tf.function
def train_step(image, labels, objects_num):
    with tf.GradientTape() as tape:
        outputs = YOLO(image)
        class_end = CELL_SIZE * CELL_SIZE * NUM_CLASSES
        conf_end = class_end + CELL_SIZE * CELL_SIZE * BOXES_PER_CELL
        class_probs = tf.reshape(outputs[:, 0:class_end], (-1, 7, 7, 20))
        confs = tf.reshape(outputs[:, class_end:conf_end], (-1, 7, 7, 2))
        boxes = tf.reshape(outputs[:, conf_end:], (-1, 7, 7, 2*4))
        predicts = tf.concat([class_probs, confs, boxes], 3)
        # Case if len of last iteration is smaller than BATCH_SIZE
        if outputs.shape[0] < BATCH_SIZE:
            batch_size = outputs.shape[0]
        else:
            batch_size = BATCH_SIZE
        loss = yolo_loss(predicts, labels, objects_num, batch_size)
        train_loss_metric(loss)

    grads = tape.gradient(loss, YOLO.trainable_weights)
    optimizer.apply_gradients(zip(grads, YOLO.trainable_weights))

# %%
from datetime import datetime

# %%
print("{}, start training.".format(datetime.now()))
for i in range(EPOCHS):
    train_loss_metric.reset_states()
    ckpt.epoch.assign_add(1)

    for idx, (image, labels, objects_num) in enumerate(dataset):
        train_step(image, labels, objects_num)

    print("{}, Epoch {}: loss {:.2f}".format(datetime.now(), i+1, train_loss_metric.result()))

    save_path = manager.save()
    print("Saved checkpoint for epoch {}: {}".format(int(ckpt.epoch), save_path))
# Out:
# 2023-11-20 19:59:52.561331, start training.
# 2023-11-20 20:06:18.287239, Epoch 1: loss 2702.54
# Saved checkpoint for epoch 1: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-1
# 2023-11-20 20:07:16.040943, Epoch 2: loss 21.70
# Saved checkpoint for epoch 2: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-2
# 2023-11-20 20:08:14.426601, Epoch 3: loss 20.83
# Saved checkpoint for epoch 3: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-3
# 2023-11-20 20:09:10.238152, Epoch 4: loss 20.46
# Saved checkpoint for epoch 4: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-4
# 2023-11-20 20:10:09.286534, Epoch 5: loss 20.16
# Saved checkpoint for epoch 5: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-5
# 2023-11-20 20:11:05.290179, Epoch 6: loss 19.90
# Saved checkpoint for epoch 6: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-6
# 2023-11-20 20:12:01.229627, Epoch 7: loss 19.48
# Saved checkpoint for epoch 7: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-7
# 2023-11-20 20:13:00.185491, Epoch 8: loss 19.02
# Saved checkpoint for epoch 8: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-8
# 2023-11-20 20:13:56.239395, Epoch 9: loss 18.56
# Saved checkpoint for epoch 9: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-9
# 2023-11-20 20:14:55.244910, Epoch 10: loss 18.31
# Saved checkpoint for epoch 10: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-10
# 2023-11-20 20:15:50.845301, Epoch 11: loss 18.06
# Saved checkpoint for epoch 11: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-11
# 2023-11-20 20:16:49.762451, Epoch 12: loss 18.24
# Saved checkpoint for epoch 12: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-12
# 2023-11-20 20:17:45.519564, Epoch 13: loss 18.18
# Saved checkpoint for epoch 13: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-13
# 2023-11-20 20:18:41.315627, Epoch 14: loss 18.03
# Saved checkpoint for epoch 14: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-14
# 2023-11-20 20:19:40.022389, Epoch 15: loss 17.86
# Saved checkpoint for epoch 15: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-15
# 2023-11-20 20:20:35.867120, Epoch 16: loss 17.60
# Saved checkpoint for epoch 16: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-16
# 2023-11-20 20:21:34.977283, Epoch 17: loss 17.37
# Saved checkpoint for epoch 17: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-17
# 2023-11-20 20:22:31.160220, Epoch 18: loss 16.96
# Saved checkpoint for epoch 18: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-18
# 2023-11-20 20:23:30.407802, Epoch 19: loss 16.79
# Saved checkpoint for epoch 19: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-19
# 2023-11-20 20:24:26.351335, Epoch 20: loss 16.45
# Saved checkpoint for epoch 20: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-20
# 2023-11-20 20:25:22.125324, Epoch 21: loss 15.89
# Saved checkpoint for epoch 21: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-21
# 2023-11-20 20:26:20.910917, Epoch 22: loss 15.15
# Saved checkpoint for epoch 22: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-22
# 2023-11-20 20:27:16.992340, Epoch 23: loss 14.07
# Saved checkpoint for epoch 23: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-23
# 2023-11-20 20:28:16.180356, Epoch 24: loss 12.90
# Saved checkpoint for epoch 24: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-24
# 2023-11-20 20:29:12.355255, Epoch 25: loss 11.53
# Saved checkpoint for epoch 25: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-25
# 2023-11-20 20:30:11.482354, Epoch 26: loss 10.07
# Saved checkpoint for epoch 26: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-26
# 2023-11-20 20:31:07.519465, Epoch 27: loss 9.00
# Saved checkpoint for epoch 27: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-27
# 2023-11-20 20:32:06.894294, Epoch 28: loss 8.33
# Saved checkpoint for epoch 28: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-28
# 2023-11-20 20:33:05.940009, Epoch 29: loss 7.80
# Saved checkpoint for epoch 29: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-29
# 2023-11-20 20:34:01.803738, Epoch 30: loss 7.69
# Saved checkpoint for epoch 30: /content/drive/MyDrive/deep_learning/comp2/ckpts/YOLO/yolo-30

# %% [markdown]
# ## Predict Test data

# %% [markdown]
# ### process YOLO's predictions

# %%
def process_outputs(outputs):
    """
    Process YOLO outputs into bounding boxes
    """

    class_end = CELL_SIZE * CELL_SIZE * NUM_CLASSES
    conf_end = class_end + CELL_SIZE * CELL_SIZE * BOXES_PER_CELL
    class_probs = np.reshape(outputs[:, 0:class_end], (-1, 7, 7, 20))
    confs = np.reshape(outputs[:, class_end:conf_end], (-1, 7, 7, 2))
    boxes = np.reshape(outputs[:, conf_end:], (-1, 7, 7, 2*4))
    predicts = np.concatenate([class_probs, confs, boxes], 3)

    p_classes = predicts[0, :, :, 0:20]
    C = predicts[0, :, :, 20:22]
    coordinate = predicts[0, :, :, 22:]

    p_classes = np.reshape(p_classes, (CELL_SIZE, CELL_SIZE, 1, 20))
    C = np.reshape(C, (CELL_SIZE, CELL_SIZE, BOXES_PER_CELL, 1))

    P = C * p_classes
    #P's shape [7, 7, 2, 20]

    #choose the most confidence one
    max_conf = np.max(P)
    index = np.argmax(P)

    index = np.unravel_index(index, P.shape)

    class_num = index[3]
    print(class_num)

    coordinate = np.reshape(coordinate,
                            (CELL_SIZE,
                             CELL_SIZE,
                             BOXES_PER_CELL,
                             4))

    max_coordinate = coordinate[index[0], index[1], index[2], :]

    xcenter = max_coordinate[0]
    ycenter = max_coordinate[1]
    w = max_coordinate[2]
    h = max_coordinate[3]

    xcenter = (index[1] + xcenter) * (IMAGE_SIZE/float(CELL_SIZE))
    ycenter = (index[0] + ycenter) * (IMAGE_SIZE/float(CELL_SIZE))

    w = w * IMAGE_SIZE
    h = h * IMAGE_SIZE

    xmin = xcenter - w/2.0
    ymin = ycenter - h/2.0

    xmax = xmin + w
    ymax = ymin + h

    return xmin, ymin, xmax, ymax, class_num, max_conf

# %% [markdown]
# ### Build Test dataset Iterator

# %%
test_img_files = open('./pascal_voc_testing_data.txt')
test_img_dir = './VOCdevkit_test/VOC2007/JPEGImages/'
test_images = []

for line in test_img_files:
    line = line.strip()
    ss = line.split(' ')
    test_images.append(ss[0])

test_dataset = tf.data.Dataset.from_tensor_slices(test_images)

def load_img_data(image_name):
    image_file = tf.io.read_file(test_img_dir+image_name)
    image = tf.image.decode_jpeg(image_file, channels=3)

    h = tf.shape(image)[0]
    w = tf.shape(image)[1]

    image = tf.image.resize(image, size=[IMAGE_SIZE, IMAGE_SIZE])
    image = (image/255) * 2 - 1

    return image_name, image, h, w

test_dataset = test_dataset.map(load_img_data, num_parallel_calls = tf.data.experimental.AUTOTUNE)
test_dataset = test_dataset.batch(32)

# %%
ckpt = tf.train.Checkpoint(net=YOLO)
ckpt.restore(ckpt_dir + '/yolo-30')

# %%
@tf.function
def prediction_step(img):
    return YOLO(img, training=False)

# %% [markdown]
# ### Make Prediction and Output to txt file

# %%
output_dir = '/content/drive/MyDrive/deep_learning/comp2/output/'
os.makedirs(output_dir, exist_ok = True)

# %%
output_file = open(output_dir + 'test_prediction.txt', 'w')

for img_name, test_img, img_h, img_w in test_dataset:
    batch_num = img_name.shape[0]
    for i in range(batch_num):
        xmin, ymin, xmax, ymax, class_num, conf = process_outputs(prediction_step(test_img[i:i+1]))
        xmin, ymin, xmax, ymax = xmin*(img_w[i:i+1]/IMAGE_SIZE), ymin*(img_h[i:i+1]/IMAGE_SIZE), xmax*(img_w[i:i+1]/IMAGE_SIZE), ymax*(img_h[i:i+1]/IMAGE_SIZE)
        print('img_name: ', img_name[i])
        print('predict class: ', class_num)
        #img filename, xmin, ymin, xmax, ymax, class, confidence
        output_file.write(img_name[i:i+1].numpy()[0].decode('ascii')+" %d %d %d %d %d %f\n" %(xmin, ymin, xmax, ymax, class_num, conf))

output_file.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# img_name:  tf.Tensor(b'006582.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'006589.jpg', shape=(), dtype=string)
# predict class:  11
# 6
# img_name:  tf.Tensor(b'006590.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006591.jpg', shape=(), dtype=string)
# predict class:  14
# 16
# img_name:  tf.Tensor(b'006592.jpg', shape=(), dtype=string)
# predict class:  16
# 14
# img_name:  tf.Tensor(b'006594.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'006596.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'006598.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'006600.jpg', shape=(), dtype=string)
# predict class:  11
# 6
# img_name:  tf.Tensor(b'006601.jpg', shape=(), dtype=string)
# predict class:  6
# 3
# img_name:  tf.Tensor(b'006604.jpg', shape=(), dtype=string)
# predict class:  3
# 14
# img_name:  tf.Tensor(b'006607.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'006608.jpg', shape=(), dtype=string)
# predict class:  11
# 18
# img_name:  tf.Tensor(b'006613.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'006615.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006616.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006620.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006623.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006624.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006629.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006630.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'006633.jpg', shape=(), dtype=string)
# predict class:  12
# 6
# img_name:  tf.Tensor(b'006634.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006639.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006640.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006641.jpg', shape=(), dtype=string)
# predict class:  14
# 8
# img_name:  tf.Tensor(b'006642.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'006644.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006646.jpg', shape=(), dtype=string)
# predict class:  14
# 3
# img_name:  tf.Tensor(b'006649.jpg', shape=(), dtype=string)
# predict class:  3
# 14
# img_name:  tf.Tensor(b'006650.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'006651.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'006653.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006655.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006656.jpg', shape=(), dtype=string)
# predict class:  14
# 16
# img_name:  tf.Tensor(b'006659.jpg', shape=(), dtype=string)
# predict class:  16
# 14
# img_name:  tf.Tensor(b'006662.jpg', shape=(), dtype=string)
# predict class:  14
# 8
# img_name:  tf.Tensor(b'006663.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'006665.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'006669.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006672.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'006675.jpg', shape=(), dtype=string)
# predict class:  6
# 19
# img_name:  tf.Tensor(b'006676.jpg', shape=(), dtype=string)
# predict class:  19
# 14
# img_name:  tf.Tensor(b'006680.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'006683.jpg', shape=(), dtype=string)
# predict class:  18
# 6
# img_name:  tf.Tensor(b'006685.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006686.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006688.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'006691.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006692.jpg', shape=(), dtype=string)
# predict class:  14
# 5
# img_name:  tf.Tensor(b'006693.jpg', shape=(), dtype=string)
# predict class:  5
# 14
# img_name:  tf.Tensor(b'006700.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006701.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006705.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006710.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006711.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'006712.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'006713.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'006715.jpg', shape=(), dtype=string)
# predict class:  6
# 0
# img_name:  tf.Tensor(b'006716.jpg', shape=(), dtype=string)
# predict class:  0
# 6
# img_name:  tf.Tensor(b'006717.jpg', shape=(), dtype=string)
# predict class:  6
# 12
# img_name:  tf.Tensor(b'006720.jpg', shape=(), dtype=string)
# predict class:  12
# 11
# img_name:  tf.Tensor(b'006721.jpg', shape=(), dtype=string)
# predict class:  11
# 6
# img_name:  tf.Tensor(b'006723.jpg', shape=(), dtype=string)
# predict class:  6
# 6
# img_name:  tf.Tensor(b'006724.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006728.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006729.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006732.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006733.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006737.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'006741.jpg', shape=(), dtype=string)
# predict class:  6
# 11
# img_name:  tf.Tensor(b'006742.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'006743.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006744.jpg', shape=(), dtype=string)
# predict class:  14
# 8
# img_name:  tf.Tensor(b'006745.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'006746.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'006749.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006750.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'006752.jpg', shape=(), dtype=string)
# predict class:  0
# 6
# img_name:  tf.Tensor(b'006754.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006756.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'006757.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006758.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'006763.jpg', shape=(), dtype=string)
# predict class:  18
# 8
# img_name:  tf.Tensor(b'006764.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'006767.jpg', shape=(), dtype=string)
# predict class:  14
# 16
# img_name:  tf.Tensor(b'006770.jpg', shape=(), dtype=string)
# predict class:  16
# 14
# img_name:  tf.Tensor(b'006771.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006774.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006775.jpg', shape=(), dtype=string)
# predict class:  14
# 2
# img_name:  tf.Tensor(b'006776.jpg', shape=(), dtype=string)
# predict class:  2
# 14
# img_name:  tf.Tensor(b'006778.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006779.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'006780.jpg', shape=(), dtype=string)
# predict class:  6
# 18
# img_name:  tf.Tensor(b'006785.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'006787.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'006790.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006791.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006792.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'006793.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'006795.jpg', shape=(), dtype=string)
# predict class:  14
# 13
# img_name:  tf.Tensor(b'006796.jpg', shape=(), dtype=string)
# predict class:  13
# 14
# img_name:  tf.Tensor(b'006798.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006801.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006804.jpg', shape=(), dtype=string)
# predict class:  14
# 15
# img_name:  tf.Tensor(b'006807.jpg', shape=(), dtype=string)
# predict class:  15
# 12
# img_name:  tf.Tensor(b'006811.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'006812.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'006815.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'006816.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006817.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'006818.jpg', shape=(), dtype=string)
# predict class:  11
# 9
# img_name:  tf.Tensor(b'006820.jpg', shape=(), dtype=string)
# predict class:  9
# 14
# img_name:  tf.Tensor(b'006823.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006826.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006830.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006831.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'006832.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'006834.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'006837.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'006843.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'006846.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'006851.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'006853.jpg', shape=(), dtype=string)
# predict class:  6
# 6
# img_name:  tf.Tensor(b'006854.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006856.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006857.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006861.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'006863.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'006870.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006871.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006872.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006873.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'006875.jpg', shape=(), dtype=string)
# predict class:  12
# 11
# img_name:  tf.Tensor(b'006877.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'006879.jpg', shape=(), dtype=string)
# predict class:  14
# 8
# img_name:  tf.Tensor(b'006881.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'006882.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'006885.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'006888.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'006889.jpg', shape=(), dtype=string)
# predict class:  0
# 11
# img_name:  tf.Tensor(b'006890.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'006891.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006894.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006895.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'006897.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'006898.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006901.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'006902.jpg', shape=(), dtype=string)
# predict class:  11
# 7
# img_name:  tf.Tensor(b'006904.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'006905.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006906.jpg', shape=(), dtype=string)
# predict class:  14
# 5
# img_name:  tf.Tensor(b'006907.jpg', shape=(), dtype=string)
# predict class:  5
# 6
# img_name:  tf.Tensor(b'006913.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006915.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006920.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006921.jpg', shape=(), dtype=string)
# predict class:  14
# 8
# img_name:  tf.Tensor(b'006923.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'006925.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006926.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006927.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006928.jpg', shape=(), dtype=string)
# predict class:  14
# 3
# img_name:  tf.Tensor(b'006929.jpg', shape=(), dtype=string)
# predict class:  3
# 14
# img_name:  tf.Tensor(b'006936.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006937.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006938.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006941.jpg', shape=(), dtype=string)
# predict class:  14
# 1
# img_name:  tf.Tensor(b'006942.jpg', shape=(), dtype=string)
# predict class:  1
# 14
# img_name:  tf.Tensor(b'006946.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006951.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006954.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006955.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006957.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006960.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006961.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006964.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'006967.jpg', shape=(), dtype=string)
# predict class:  11
# 11
# img_name:  tf.Tensor(b'006969.jpg', shape=(), dtype=string)
# predict class:  11
# 18
# img_name:  tf.Tensor(b'006970.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'006973.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006974.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006975.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006977.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'006978.jpg', shape=(), dtype=string)
# predict class:  18
# 6
# img_name:  tf.Tensor(b'006979.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006980.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006982.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006984.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'006985.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'006986.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006991.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'006992.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'006993.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'006996.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'006997.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'006998.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'006999.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'007000.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007001.jpg', shape=(), dtype=string)
# predict class:  6
# 0
# img_name:  tf.Tensor(b'007005.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'007010.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007012.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007013.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007014.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007015.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007017.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007019.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007024.jpg', shape=(), dtype=string)
# predict class:  14
# 3
# img_name:  tf.Tensor(b'007026.jpg', shape=(), dtype=string)
# predict class:  3
# 14
# img_name:  tf.Tensor(b'007027.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007028.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'007030.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'007032.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007034.jpg', shape=(), dtype=string)
# predict class:  6
# 3
# img_name:  tf.Tensor(b'007037.jpg', shape=(), dtype=string)
# predict class:  3
# 6
# img_name:  tf.Tensor(b'007041.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007043.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007044.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007047.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007051.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007053.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007055.jpg', shape=(), dtype=string)
# predict class:  11
# 6
# img_name:  tf.Tensor(b'007057.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007060.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007061.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007063.jpg', shape=(), dtype=string)
# predict class:  14
# 3
# img_name:  tf.Tensor(b'007066.jpg', shape=(), dtype=string)
# predict class:  3
# 6
# img_name:  tf.Tensor(b'007067.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007069.jpg', shape=(), dtype=string)
# predict class:  14
# 2
# img_name:  tf.Tensor(b'007076.jpg', shape=(), dtype=string)
# predict class:  2
# 14
# img_name:  tf.Tensor(b'007081.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007082.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007085.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007087.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'007091.jpg', shape=(), dtype=string)
# predict class:  7
# 16
# img_name:  tf.Tensor(b'007094.jpg', shape=(), dtype=string)
# predict class:  16
# 0
# img_name:  tf.Tensor(b'007096.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'007098.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'007099.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'007102.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007103.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007106.jpg', shape=(), dtype=string)
# predict class:  11
# 6
# img_name:  tf.Tensor(b'007107.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007110.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007111.jpg', shape=(), dtype=string)
# predict class:  6
# 6
# img_name:  tf.Tensor(b'007112.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007115.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007116.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007118.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007119.jpg', shape=(), dtype=string)
# predict class:  14
# 13
# img_name:  tf.Tensor(b'007120.jpg', shape=(), dtype=string)
# predict class:  13
# 6
# img_name:  tf.Tensor(b'007124.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007126.jpg', shape=(), dtype=string)
# predict class:  14
# 9
# img_name:  tf.Tensor(b'007127.jpg', shape=(), dtype=string)
# predict class:  9
# 14
# img_name:  tf.Tensor(b'007131.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007134.jpg', shape=(), dtype=string)
# predict class:  14
# 3
# img_name:  tf.Tensor(b'007135.jpg', shape=(), dtype=string)
# predict class:  3
# 14
# img_name:  tf.Tensor(b'007136.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007137.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007142.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007143.jpg', shape=(), dtype=string)
# predict class:  6
# 11
# img_name:  tf.Tensor(b'007145.jpg', shape=(), dtype=string)
# predict class:  11
# 0
# img_name:  tf.Tensor(b'007155.jpg', shape=(), dtype=string)
# predict class:  0
# 5
# img_name:  tf.Tensor(b'007156.jpg', shape=(), dtype=string)
# predict class:  5
# 0
# img_name:  tf.Tensor(b'007157.jpg', shape=(), dtype=string)
# predict class:  0
# 8
# img_name:  tf.Tensor(b'007158.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'007160.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007161.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007164.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007169.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007170.jpg', shape=(), dtype=string)
# predict class:  14
# 13
# img_name:  tf.Tensor(b'007171.jpg', shape=(), dtype=string)
# predict class:  13
# 3
# img_name:  tf.Tensor(b'007173.jpg', shape=(), dtype=string)
# predict class:  3
# 14
# img_name:  tf.Tensor(b'007175.jpg', shape=(), dtype=string)
# predict class:  14
# 1
# img_name:  tf.Tensor(b'007176.jpg', shape=(), dtype=string)
# predict class:  1
# 14
# img_name:  tf.Tensor(b'007178.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007179.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007181.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007183.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007186.jpg', shape=(), dtype=string)
# predict class:  14
# 2
# img_name:  tf.Tensor(b'007188.jpg', shape=(), dtype=string)
# predict class:  2
# 14
# img_name:  tf.Tensor(b'007190.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007192.jpg', shape=(), dtype=string)
# predict class:  14
# 9
# img_name:  tf.Tensor(b'007195.jpg', shape=(), dtype=string)
# predict class:  9
# 8
# img_name:  tf.Tensor(b'007196.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'007198.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007199.jpg', shape=(), dtype=string)
# predict class:  14
# 2
# img_name:  tf.Tensor(b'007201.jpg', shape=(), dtype=string)
# predict class:  2
# 14
# img_name:  tf.Tensor(b'007202.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007203.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007206.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007207.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007209.jpg', shape=(), dtype=string)
# predict class:  11
# 7
# img_name:  tf.Tensor(b'007218.jpg', shape=(), dtype=string)
# predict class:  7
# 6
# img_name:  tf.Tensor(b'007220.jpg', shape=(), dtype=string)
# predict class:  6
# 2
# img_name:  tf.Tensor(b'007221.jpg', shape=(), dtype=string)
# predict class:  2
# 14
# img_name:  tf.Tensor(b'007225.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007226.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007228.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007229.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007231.jpg', shape=(), dtype=string)
# predict class:  11
# 0
# img_name:  tf.Tensor(b'007232.jpg', shape=(), dtype=string)
# predict class:  0
# 0
# img_name:  tf.Tensor(b'007233.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'007235.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007237.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007238.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007239.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007240.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007242.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007246.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007248.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007251.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'007252.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'007253.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007254.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'007255.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007257.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'007262.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'007264.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'007265.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007267.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007268.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007269.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007272.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007273.jpg', shape=(), dtype=string)
# predict class:  6
# 6
# img_name:  tf.Tensor(b'007277.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007278.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007281.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007282.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'007286.jpg', shape=(), dtype=string)
# predict class:  0
# 8
# img_name:  tf.Tensor(b'007287.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'007288.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'007290.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'007291.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007293.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007301.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007303.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'007304.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007306.jpg', shape=(), dtype=string)
# predict class:  14
# 13
# img_name:  tf.Tensor(b'007307.jpg', shape=(), dtype=string)
# predict class:  13
# 6
# img_name:  tf.Tensor(b'007309.jpg', shape=(), dtype=string)
# predict class:  6
# 12
# img_name:  tf.Tensor(b'007310.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'007312.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007313.jpg', shape=(), dtype=string)
# predict class:  14
# 9
# img_name:  tf.Tensor(b'007315.jpg', shape=(), dtype=string)
# predict class:  9
# 14
# img_name:  tf.Tensor(b'007316.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007317.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007319.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007321.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007324.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'007326.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'007328.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007331.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007332.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007333.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007335.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007337.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007338.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007339.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007340.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007341.jpg', shape=(), dtype=string)
# predict class:  6
# 2
# img_name:  tf.Tensor(b'007342.jpg', shape=(), dtype=string)
# predict class:  2
# 7
# img_name:  tf.Tensor(b'007345.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'007347.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007348.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'007349.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'007352.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007353.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007354.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007355.jpg', shape=(), dtype=string)
# predict class:  6
# 0
# img_name:  tf.Tensor(b'007357.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'007358.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007360.jpg', shape=(), dtype=string)
# predict class:  14
# 5
# img_name:  tf.Tensor(b'007362.jpg', shape=(), dtype=string)
# predict class:  5
# 14
# img_name:  tf.Tensor(b'007364.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007366.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007367.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007368.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007371.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007377.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007378.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007379.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007380.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007382.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007384.jpg', shape=(), dtype=string)
# predict class:  11
# 6
# img_name:  tf.Tensor(b'007386.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007387.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007391.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007392.jpg', shape=(), dtype=string)
# predict class:  14
# 2
# img_name:  tf.Tensor(b'007393.jpg', shape=(), dtype=string)
# predict class:  2
# 14
# img_name:  tf.Tensor(b'007395.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007397.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007399.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007400.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007401.jpg', shape=(), dtype=string)
# predict class:  14
# 9
# img_name:  tf.Tensor(b'007402.jpg', shape=(), dtype=string)
# predict class:  9
# 0
# img_name:  tf.Tensor(b'007403.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'007405.jpg', shape=(), dtype=string)
# predict class:  14
# 8
# img_name:  tf.Tensor(b'007406.jpg', shape=(), dtype=string)
# predict class:  8
# 2
# img_name:  tf.Tensor(b'007407.jpg', shape=(), dtype=string)
# predict class:  2
# 14
# img_name:  tf.Tensor(b'007409.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007412.jpg', shape=(), dtype=string)
# predict class:  6
# 6
# img_name:  tf.Tensor(b'007415.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007418.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007420.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007423.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007426.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007428.jpg', shape=(), dtype=string)
# predict class:  11
# 6
# img_name:  tf.Tensor(b'007429.jpg', shape=(), dtype=string)
# predict class:  6
# 15
# img_name:  tf.Tensor(b'007430.jpg', shape=(), dtype=string)
# predict class:  15
# 11
# img_name:  tf.Tensor(b'007434.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'007440.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007441.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007442.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007444.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007447.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'007450.jpg', shape=(), dtype=string)
# predict class:  18
# 6
# img_name:  tf.Tensor(b'007452.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007453.jpg', shape=(), dtype=string)
# predict class:  14
# 3
# img_name:  tf.Tensor(b'007455.jpg', shape=(), dtype=string)
# predict class:  3
# 14
# img_name:  tf.Tensor(b'007456.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007459.jpg', shape=(), dtype=string)
# predict class:  14
# 2
# img_name:  tf.Tensor(b'007462.jpg', shape=(), dtype=string)
# predict class:  2
# 7
# img_name:  tf.Tensor(b'007463.jpg', shape=(), dtype=string)
# predict class:  7
# 0
# img_name:  tf.Tensor(b'007464.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'007469.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007471.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007472.jpg', shape=(), dtype=string)
# predict class:  14
# 8
# img_name:  tf.Tensor(b'007473.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'007476.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007478.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'007485.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007487.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007488.jpg', shape=(), dtype=string)
# predict class:  14
# 9
# img_name:  tf.Tensor(b'007492.jpg', shape=(), dtype=string)
# predict class:  9
# 10
# img_name:  tf.Tensor(b'007494.jpg', shape=(), dtype=string)
# predict class:  10
# 6
# img_name:  tf.Tensor(b'007495.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007496.jpg', shape=(), dtype=string)
# predict class:  14
# 15
# img_name:  tf.Tensor(b'007499.jpg', shape=(), dtype=string)
# predict class:  15
# 14
# img_name:  tf.Tensor(b'007500.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007501.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'007502.jpg', shape=(), dtype=string)
# predict class:  0
# 6
# img_name:  tf.Tensor(b'007504.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007505.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007507.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007508.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007509.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'007510.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'007512.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007514.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007515.jpg', shape=(), dtype=string)
# predict class:  11
# 12
# img_name:  tf.Tensor(b'007516.jpg', shape=(), dtype=string)
# predict class:  12
# 5
# img_name:  tf.Tensor(b'007518.jpg', shape=(), dtype=string)
# predict class:  5
# 14
# img_name:  tf.Tensor(b'007520.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007522.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007529.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007532.jpg', shape=(), dtype=string)
# predict class:  14
# 16
# img_name:  tf.Tensor(b'007534.jpg', shape=(), dtype=string)
# predict class:  16
# 14
# img_name:  tf.Tensor(b'007539.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007541.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007542.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'007545.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'007548.jpg', shape=(), dtype=string)
# predict class:  7
# 11
# img_name:  tf.Tensor(b'007549.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'007550.jpg', shape=(), dtype=string)
# predict class:  14
# 3
# img_name:  tf.Tensor(b'007552.jpg', shape=(), dtype=string)
# predict class:  3
# 14
# img_name:  tf.Tensor(b'007553.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007554.jpg', shape=(), dtype=string)
# predict class:  11
# 6
# img_name:  tf.Tensor(b'007556.jpg', shape=(), dtype=string)
# predict class:  6
# 18
# img_name:  tf.Tensor(b'007557.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'007560.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007561.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007562.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007564.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007567.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007569.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007573.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007574.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007577.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007580.jpg', shape=(), dtype=string)
# predict class:  6
# 9
# img_name:  tf.Tensor(b'007581.jpg', shape=(), dtype=string)
# predict class:  9
# 7
# img_name:  tf.Tensor(b'007582.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'007583.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007584.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007587.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007588.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007589.jpg', shape=(), dtype=string)
# predict class:  6
# 6
# img_name:  tf.Tensor(b'007591.jpg', shape=(), dtype=string)
# predict class:  6
# 13
# img_name:  tf.Tensor(b'007593.jpg', shape=(), dtype=string)
# predict class:  13
# 14
# img_name:  tf.Tensor(b'007595.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007596.jpg', shape=(), dtype=string)
# predict class:  11
# 2
# img_name:  tf.Tensor(b'007597.jpg', shape=(), dtype=string)
# predict class:  2
# 6
# img_name:  tf.Tensor(b'007598.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007599.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007602.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007604.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007607.jpg', shape=(), dtype=string)
# predict class:  14
# 2
# img_name:  tf.Tensor(b'007608.jpg', shape=(), dtype=string)
# predict class:  2
# 14
# img_name:  tf.Tensor(b'007609.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007610.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007613.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'007616.jpg', shape=(), dtype=string)
# predict class:  18
# 6
# img_name:  tf.Tensor(b'007617.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007620.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007623.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007625.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'007627.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'007628.jpg', shape=(), dtype=string)
# predict class:  14
# 2
# img_name:  tf.Tensor(b'007630.jpg', shape=(), dtype=string)
# predict class:  2
# 6
# img_name:  tf.Tensor(b'007632.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007634.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007635.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007636.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007638.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'007641.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007643.jpg', shape=(), dtype=string)
# predict class:  14
# 8
# img_name:  tf.Tensor(b'007644.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'007645.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007646.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007648.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007651.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007652.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007658.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'007659.jpg', shape=(), dtype=string)
# predict class:  18
# 13
# img_name:  tf.Tensor(b'007660.jpg', shape=(), dtype=string)
# predict class:  13
# 14
# img_name:  tf.Tensor(b'007661.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007665.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007669.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007674.jpg', shape=(), dtype=string)
# predict class:  6
# 18
# img_name:  tf.Tensor(b'007676.jpg', shape=(), dtype=string)
# predict class:  18
# 2
# img_name:  tf.Tensor(b'007681.jpg', shape=(), dtype=string)
# predict class:  2
# 14
# img_name:  tf.Tensor(b'007684.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007686.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007689.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'007690.jpg', shape=(), dtype=string)
# predict class:  7
# 6
# img_name:  tf.Tensor(b'007693.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007695.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'007698.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'007700.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007701.jpg', shape=(), dtype=string)
# predict class:  14
# 2
# img_name:  tf.Tensor(b'007703.jpg', shape=(), dtype=string)
# predict class:  2
# 14
# img_name:  tf.Tensor(b'007706.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007707.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007708.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007710.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007711.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007714.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007716.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007717.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007719.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007722.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007725.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007726.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007728.jpg', shape=(), dtype=string)
# predict class:  14
# 9
# img_name:  tf.Tensor(b'007730.jpg', shape=(), dtype=string)
# predict class:  9
# 14
# img_name:  tf.Tensor(b'007733.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007734.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007737.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007738.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007739.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007741.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007744.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007747.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007750.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007752.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007755.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007756.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'007757.jpg', shape=(), dtype=string)
# predict class:  6
# 6
# img_name:  tf.Tensor(b'007759.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'007761.jpg', shape=(), dtype=string)
# predict class:  14
# 3
# img_name:  tf.Tensor(b'007764.jpg', shape=(), dtype=string)
# predict class:  3
# 14
# img_name:  tf.Tensor(b'007769.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007770.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007771.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'007774.jpg', shape=(), dtype=string)
# predict class:  11
# 0
# img_name:  tf.Tensor(b'007778.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'007780.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007782.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007783.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'007784.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'007785.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007787.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'007788.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'007789.jpg', shape=(), dtype=string)
# predict class:  0
# 9
# img_name:  tf.Tensor(b'007792.jpg', shape=(), dtype=string)
# predict class:  9
# 18
# img_name:  tf.Tensor(b'007794.jpg', shape=(), dtype=string)
# predict class:  18
# 2
# img_name:  tf.Tensor(b'007796.jpg', shape=(), dtype=string)
# predict class:  2
# 6
# img_name:  tf.Tensor(b'007797.jpg', shape=(), dtype=string)
# predict class:  6
# 0
# ...
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009563.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009564.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009569.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009570.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009572.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009574.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'009575.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'009578.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009581.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009582.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009583.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009589.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009590.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009592.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009593.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009594.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009595.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009599.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009601.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009602.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'009604.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'009606.jpg', shape=(), dtype=string)
# predict class:  14
# 10
# img_name:  tf.Tensor(b'009607.jpg', shape=(), dtype=string)
# predict class:  10
# 14
# img_name:  tf.Tensor(b'009608.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009610.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009612.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'009616.jpg', shape=(), dtype=string)
# predict class:  12
# 8
# img_name:  tf.Tensor(b'009622.jpg', shape=(), dtype=string)
# predict class:  8
# 12
# img_name:  tf.Tensor(b'009624.jpg', shape=(), dtype=string)
# predict class:  12
# 18
# img_name:  tf.Tensor(b'009625.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'009626.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009628.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009630.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009631.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009632.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009633.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'009635.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'009639.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'009640.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'009642.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009643.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009645.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009646.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'009648.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'009651.jpg', shape=(), dtype=string)
# predict class:  14
# 13
# img_name:  tf.Tensor(b'009652.jpg', shape=(), dtype=string)
# predict class:  13
# 14
# img_name:  tf.Tensor(b'009653.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009657.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009660.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009661.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009662.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009663.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009665.jpg', shape=(), dtype=string)
# predict class:  14
# 17
# img_name:  tf.Tensor(b'009669.jpg', shape=(), dtype=string)
# predict class:  17
# 7
# img_name:  tf.Tensor(b'009672.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'009673.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009674.jpg', shape=(), dtype=string)
# predict class:  6
# 6
# img_name:  tf.Tensor(b'009675.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009677.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009680.jpg', shape=(), dtype=string)
# predict class:  6
# 18
# img_name:  tf.Tensor(b'009682.jpg', shape=(), dtype=string)
# predict class:  18
# 0
# img_name:  tf.Tensor(b'009683.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'009688.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009689.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009690.jpg', shape=(), dtype=string)
# predict class:  14
# 3
# img_name:  tf.Tensor(b'009694.jpg', shape=(), dtype=string)
# predict class:  3
# 11
# img_name:  tf.Tensor(b'009696.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'009697.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009701.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009704.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009705.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009708.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009714.jpg', shape=(), dtype=string)
# predict class:  14
# 10
# img_name:  tf.Tensor(b'009715.jpg', shape=(), dtype=string)
# predict class:  10
# 14
# img_name:  tf.Tensor(b'009716.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'009720.jpg', shape=(), dtype=string)
# predict class:  7
# 0
# img_name:  tf.Tensor(b'009722.jpg', shape=(), dtype=string)
# predict class:  0
# 18
# img_name:  tf.Tensor(b'009723.jpg', shape=(), dtype=string)
# predict class:  18
# 6
# img_name:  tf.Tensor(b'009725.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009727.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009728.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'009730.jpg', shape=(), dtype=string)
# predict class:  18
# 12
# img_name:  tf.Tensor(b'009731.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'009739.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009740.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009741.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009742.jpg', shape=(), dtype=string)
# predict class:  14
# 2
# img_name:  tf.Tensor(b'009744.jpg', shape=(), dtype=string)
# predict class:  2
# 14
# img_name:  tf.Tensor(b'009750.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'009751.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'009752.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009753.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009757.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'009759.jpg', shape=(), dtype=string)
# predict class:  7
# 16
# img_name:  tf.Tensor(b'009760.jpg', shape=(), dtype=string)
# predict class:  16
# 11
# img_name:  tf.Tensor(b'009765.jpg', shape=(), dtype=string)
# predict class:  11
# 7
# img_name:  tf.Tensor(b'009766.jpg', shape=(), dtype=string)
# predict class:  7
# 12
# img_name:  tf.Tensor(b'009768.jpg', shape=(), dtype=string)
# predict class:  12
# 6
# img_name:  tf.Tensor(b'009769.jpg', shape=(), dtype=string)
# predict class:  6
# 6
# img_name:  tf.Tensor(b'009770.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009771.jpg', shape=(), dtype=string)
# predict class:  14
# 7
# img_name:  tf.Tensor(b'009775.jpg', shape=(), dtype=string)
# predict class:  7
# 14
# img_name:  tf.Tensor(b'009777.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009779.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009782.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009783.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009784.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009786.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009787.jpg', shape=(), dtype=string)
# predict class:  14
# 1
# img_name:  tf.Tensor(b'009788.jpg', shape=(), dtype=string)
# predict class:  1
# 14
# img_name:  tf.Tensor(b'009791.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009793.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009795.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009798.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009799.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009802.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'009803.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'009804.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009806.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'009811.jpg', shape=(), dtype=string)
# predict class:  0
# 6
# img_name:  tf.Tensor(b'009812.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009814.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009815.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009817.jpg', shape=(), dtype=string)
# predict class:  14
# 16
# img_name:  tf.Tensor(b'009818.jpg', shape=(), dtype=string)
# predict class:  16
# 14
# img_name:  tf.Tensor(b'009820.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009821.jpg', shape=(), dtype=string)
# predict class:  6
# 0
# img_name:  tf.Tensor(b'009824.jpg', shape=(), dtype=string)
# predict class:  0
# 8
# img_name:  tf.Tensor(b'009826.jpg', shape=(), dtype=string)
# predict class:  8
# 6
# img_name:  tf.Tensor(b'009827.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009829.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'009835.jpg', shape=(), dtype=string)
# predict class:  0
# 14
# img_name:  tf.Tensor(b'009837.jpg', shape=(), dtype=string)
# predict class:  14
# 3
# img_name:  tf.Tensor(b'009838.jpg', shape=(), dtype=string)
# predict class:  3
# 19
# img_name:  tf.Tensor(b'009840.jpg', shape=(), dtype=string)
# predict class:  19
# 14
# img_name:  tf.Tensor(b'009843.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'009844.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'009846.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'009847.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'009849.jpg', shape=(), dtype=string)
# predict class:  14
# 1
# img_name:  tf.Tensor(b'009850.jpg', shape=(), dtype=string)
# predict class:  1
# 14
# img_name:  tf.Tensor(b'009853.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009854.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009856.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009857.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009861.jpg', shape=(), dtype=string)
# predict class:  14
# 8
# img_name:  tf.Tensor(b'009864.jpg', shape=(), dtype=string)
# predict class:  8
# 14
# img_name:  tf.Tensor(b'009866.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009871.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009873.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009875.jpg', shape=(), dtype=string)
# predict class:  14
# 0
# img_name:  tf.Tensor(b'009876.jpg', shape=(), dtype=string)
# predict class:  0
# 6
# img_name:  tf.Tensor(b'009883.jpg', shape=(), dtype=string)
# predict class:  6
# 5
# img_name:  tf.Tensor(b'009885.jpg', shape=(), dtype=string)
# predict class:  5
# 18
# img_name:  tf.Tensor(b'009888.jpg', shape=(), dtype=string)
# predict class:  18
# 11
# img_name:  tf.Tensor(b'009889.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'009890.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009891.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009892.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009893.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009895.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009899.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009901.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009903.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009906.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009907.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009909.jpg', shape=(), dtype=string)
# predict class:  14
# 13
# img_name:  tf.Tensor(b'009910.jpg', shape=(), dtype=string)
# predict class:  13
# 14
# img_name:  tf.Tensor(b'009912.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009914.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009915.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009916.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009919.jpg', shape=(), dtype=string)
# predict class:  14
# 16
# img_name:  tf.Tensor(b'009921.jpg', shape=(), dtype=string)
# predict class:  16
# 14
# img_name:  tf.Tensor(b'009922.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009924.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009925.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009927.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009928.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009929.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009930.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'009931.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'009933.jpg', shape=(), dtype=string)
# predict class:  14
# 12
# img_name:  tf.Tensor(b'009934.jpg', shape=(), dtype=string)
# predict class:  12
# 14
# img_name:  tf.Tensor(b'009936.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009937.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009941.jpg', shape=(), dtype=string)
# predict class:  14
# 6
# img_name:  tf.Tensor(b'009943.jpg', shape=(), dtype=string)
# predict class:  6
# 14
# img_name:  tf.Tensor(b'009951.jpg', shape=(), dtype=string)
# predict class:  14
# 18
# img_name:  tf.Tensor(b'009952.jpg', shape=(), dtype=string)
# predict class:  18
# 14
# img_name:  tf.Tensor(b'009953.jpg', shape=(), dtype=string)
# predict class:  14
# 11
# img_name:  tf.Tensor(b'009956.jpg', shape=(), dtype=string)
# predict class:  11
# 14
# img_name:  tf.Tensor(b'009957.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009960.jpg', shape=(), dtype=string)
# predict class:  14
# 14
# img_name:  tf.Tensor(b'009962.jpg', shape=(), dtype=string)
# predict class:  14
# 13
# img_name:  tf.Tensor(b'009963.jpg', shape=(), dtype=string)
# predict class:  13

# %% [markdown]
# ### Run Evaluation Metric

# %%
import sys
sys.path.insert(0, './evaluate')

# %%
import evaluate
#evaluate.evaluate("input prediction file name", "desire output csv file name")
evaluate.evaluate(output_dir + 'test_prediction.txt', output_dir + 'output_file.csv')
# Out:
# End Evalutation

# %% [markdown]
# ## Visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2

# %%
np_img = cv2.imread('./VOCdevkit_test/VOC2007/JPEGImages/000002.jpg')
resized_img = cv2.resize(np_img, (IMAGE_SIZE, IMAGE_SIZE))
np_img = cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB)
resized_img = np_img
np_img = np_img.astype(np.float32)
np_img = np_img / 255.0 * 2 - 1
np_img = np.reshape(np_img, (1, IMAGE_SIZE, IMAGE_SIZE, 3))

y_pred = YOLO(np_img, training=False)
xmin, ymin, xmax, ymax, class_num, conf = process_outputs(y_pred)
class_name = classes_name[class_num]
cv2.rectangle(resized_img, (int(xmin), int(ymin)), (int(xmax), int(ymax)), (0, 255, 255), 3)
cv2.putText(resized_img, class_name, (0, 200), 2, 1.5, (0, 255, 255), 2)

plt.imshow(resized_img)
plt.show()
# Out:
# 14

# %%
np_img = cv2.imread('./VOCdevkit_test/VOC2007/JPEGImages/000968.jpg')
resized_img = cv2.resize(np_img, (IMAGE_SIZE, IMAGE_SIZE))
np_img = cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB)
resized_img = np_img
np_img = np_img.astype(np.float32)
np_img = np_img / 255.0 * 2 - 1
np_img = np.reshape(np_img, (1, IMAGE_SIZE, IMAGE_SIZE, 3))

y_pred = YOLO(np_img, training=False)
xmin, ymin, xmax, ymax, class_num, conf = process_outputs(y_pred)
class_name = classes_name[class_num]
cv2.rectangle(resized_img, (int(xmin), int(ymin)), (int(xmax), int(ymax)), (0, 255, 255), 3)
cv2.putText(resized_img, class_name, (0, 200), 2, 1.5, (0, 255, 255), 2)

plt.imshow(resized_img)
plt.show()
# Out:
# 0
